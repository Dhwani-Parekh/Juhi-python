# %%
import pandas as pd

# %% [markdown]
# ## Objective:
# Analyze Market Share trends by Cities (Mumbai, Bangalore, Delhi, Chennai, Kolkata, Hyderabad)
#
# To understand the churn pattern of users i.e. in which states/cities we are seeing a major movement of users to other carriers
#
# Comparison of the top 10 pin codes, where Airtel has lost market share in this period and other operators like Reliance Jio has witnessed a significant surge
#
# Suggest a distinctive strategy for Airtel to retain its users across 3 different states
#
# Specify the assumptions taken during the analysis
#
# ## Data Dictionary:
# date: Date of which the record is captured
#
# udid: Unique identifier of the user/customer
#
#
# Operator: Mobile operator of the user
#
# State: State where the user is spotted on that day
#
# City: City where the user is spotted on that day
#
# zipcode: ZIP where the user is spotted on that day
#
# Ad_Requests: Mobile traffic in terms of ad-requests reflects user's quantitative activity on that day using that operator

# %%
data = pd.read_csv('../Data/rawdata.csv')

# %%
data.head()
# Out:
#          date                                      udid        operator  \
# 0  2018-04-15  00000902bb5bea2d8f865e1c6b0ace6abf6725d7             Jio
# 1  2018-05-15  00002cd8fd6d3ae94d385102c85d40870430bed3  Vodafone Essar
# 2  2018-05-15  0000c379b9f8c3476e3fb7e86ec0b8ccc3f6b90c             Jio
# 3  2018-04-15  0001265ed98b8c1ac1f208e68a05ebcd501aca8b             Jio
# 4  2018-05-15  0001cbb4b1428ad3f0175532b8c8e2b108f32d08             Jio
#
#            state            city  zipcode  ad_requests
# 0     TAMIL NADU          PALANI   624601            1
# 1        GUJARAT       AHMEDABAD   380014            3
# 2  UTTAR PRADESH       CHANDAULI   232101            2
# 3          ASSAM  NORTH GUWAHATI   781008           77
# 4      KARNATAKA       BANGALORE   560066            6

# %%
data.size
# Out:
# 130320337

# %% [markdown]
# ## Churn pattern

# %%
#State level
data_state = data[['date','udid','operator','state']].drop_duplicates()
print data_state.size
data_state.head()
# Out:
# 68976844
#          date                                      udid        operator  \
# 0  2018-04-15  00000902bb5bea2d8f865e1c6b0ace6abf6725d7             Jio
# 1  2018-05-15  00002cd8fd6d3ae94d385102c85d40870430bed3  Vodafone Essar
# 2  2018-05-15  0000c379b9f8c3476e3fb7e86ec0b8ccc3f6b90c             Jio
# 3  2018-04-15  0001265ed98b8c1ac1f208e68a05ebcd501aca8b             Jio
# 4  2018-05-15  0001cbb4b1428ad3f0175532b8c8e2b108f32d08             Jio
#
#            state
# 0     TAMIL NADU
# 1        GUJARAT
# 2  UTTAR PRADESH
# 3          ASSAM
# 4      KARNATAKA

# %%
print data_state.operator.unique()
print data_state.date.unique()
# Out:
# ['Jio' 'Vodafone Essar' 'Bharti Airtel' 'Idea']
# ['2018-04-15' '2018-05-15']

# %%
#Replace operators by numbers and dates by months
df1 = data_state.replace({'Jio': 1, 'Vodafone Essar': 2, 'Bharti Airtel':3, 'Idea':4})
df1 = df1.replace({'2018-04-15': 'Apr', '2018-05-15': 'May'})
df1.head()
# Out:
#   date                                      udid  operator          state
# 0  Apr  00000902bb5bea2d8f865e1c6b0ace6abf6725d7         1     TAMIL NADU
# 1  May  00002cd8fd6d3ae94d385102c85d40870430bed3         2        GUJARAT
# 2  May  0000c379b9f8c3476e3fb7e86ec0b8ccc3f6b90c         1  UTTAR PRADESH
# 3  Apr  0001265ed98b8c1ac1f208e68a05ebcd501aca8b         1          ASSAM
# 4  May  0001cbb4b1428ad3f0175532b8c8e2b108f32d08         1      KARNATAKA

# %%
df1_apr = df1[df1['date'] == 'Apr']
df1_may = df1[df1['date'] == 'May']

# %%
df1_apr.head()
df1_may.head()

print df1_apr.size
print df1_may.size
# Out:
# 34449024
# 34527820

# %%
#Churn at national level
country = pd.merge(df1_apr[['date','udid','operator']], df1_may[['date','udid','operator']], how='left', on= ['udid','operator'] ,indicator=True, suffixes=('_x', '_y'))

# %%
country.head()
# Out:
#   date_x                                      udid  operator date_y _merge
# 0    Apr  00000902bb5bea2d8f865e1c6b0ace6abf6725d7         1    May   both
# 1    Apr  0001265ed98b8c1ac1f208e68a05ebcd501aca8b         1    May   both
# 2    Apr  0003610ce98164faaafc131a01402eac5a87f2a3         1    May   both
# 3    Apr  0004533e17eeff9b25540908ea1e0c8848da89f0         2    May   both
# 4    Apr  0004b5b18802f8486339eb3daa04f633dcbc1c7c         1    May   both

# %%
country._merge.unique()
# Out:
# [both, left_only]
# Categories (2, object): [both, left_only]

# %%
#total customers in the country (assuming every operator to have a new customer even if 1 person has 2 phones)
print 'Total connections =',country.size

#customers who churned
print 'Churned = ',country[country['_merge'] == 'left_only'].size

#%ge churn
print '%age churned = ',country[country['_merge'] == 'left_only'].size/country.size.astype(float)

#customers who stayed
print 'Loyal = ',country[country['_merge'] == 'both'].size
# Out:
# Total connections = 43844545
# Churned =  3467535
# %age churned =  0.0790870335181
# Loyal =  40377010

# %%
#Churn at state level
state = pd.merge(df1_apr, df1_may, how='left', on= ['udid','operator','state'] ,indicator=True, suffixes=('_x', '_y'))
state.head()
# Out:
#   date_x                                      udid  operator          state  \
# 0    Apr  00000902bb5bea2d8f865e1c6b0ace6abf6725d7         1     TAMIL NADU
# 1    Apr  0001265ed98b8c1ac1f208e68a05ebcd501aca8b         1          ASSAM
# 2    Apr  0003610ce98164faaafc131a01402eac5a87f2a3         1    MAHARASHTRA
# 3    Apr  0004533e17eeff9b25540908ea1e0c8848da89f0         2  UTTAR PRADESH
# 4    Apr  0004b5b18802f8486339eb3daa04f633dcbc1c7c         1          ASSAM
#
#   date_y _merge
# 0    May   both
# 1    May   both
# 2    May   both
# 3    May   both
# 4    May   both

# %%
state._merge.unique()
# Out:
# [both, left_only]
# Categories (2, object): [both, left_only]

# %%
state[(state['_merge'] == 'left_only') & (state['date_y'].notnull())]
# Out:
# Empty DataFrame
# Columns: [date_x, udid, operator, state, date_y, _merge]
# Index: []

# %%
state[pd.isnull(state['state'])]
# Out:
# Empty DataFrame
# Columns: [date_x, udid, operator, state, date_y, _merge]
# Index: []

# %%
state[state['date_y'].notnull()]
# Out:
#         date_x                                      udid  operator  \
# 0          Apr  00000902bb5bea2d8f865e1c6b0ace6abf6725d7         1
# 1          Apr  0001265ed98b8c1ac1f208e68a05ebcd501aca8b         1
# 2          Apr  0003610ce98164faaafc131a01402eac5a87f2a3         1
# 3          Apr  0004533e17eeff9b25540908ea1e0c8848da89f0         2
# 4          Apr  0004b5b18802f8486339eb3daa04f633dcbc1c7c         1
# 5          Apr  0005502bacc89217da7dae4d4a43f333a9f6f046         2
# 6          Apr  0005bfef699aba30aa6fccf4ec54f646ad7316d7         2
# 7          Apr  00069ff468272664efda1c75bc034733e28ac06a         3
# 8          Apr  0006c34d3509a8951b2023eecdd2583dc2981177         3
# 11         Apr  0008de27e3e1094c42d8d2fde8f0d71e22bb9ef1         3
# 12         Apr  00096a3c74a237fe1677254a166f479a0ffde822         3
# 13         Apr  000a4b9118b664aa0f79ca4fdacf5c60fc941790         1
# 14         Apr  000b8e1aee2aef0f1fa13818e6e3c3a2dfaf658a         1
# 15         Apr  000c2ffdace91a2a851c397e118e9b1e6537031e         1
# 16         Apr  001115204481355a7b3c32b01b20eb23e7cb2448         3
# 18         Apr  0012c0694873677d19b545d5be5e058091780c56         3
# 19         Apr  001440b0bbdbec62f960de458faf41a0e68bb15a         1
# 21         Apr  001760e829b207c6c460da70a73313d33c77cb9c         1
# 22         Apr  001766706500232958a9c9cef4e4242baddfb824         1
# 23         Apr  00193ff938243b0f0d247124c6ba88adf3d3de90         3
# 24         Apr  001a4295dfbed2237c7d3ba37a43788d2b90d327         4
# 25         Apr  001a4bda1713584f3bbcb40c91e8cc7de79cb03e         1
# 26         Apr  001b645e427bc4719203af8fad6eeb662316596d         1
# 28         Apr  001dc5f79e67bfae7ebf00097d9da241f46b563e         1
# 29         Apr  001ea3985e434af4e543c3a18c4092aec0f151b9         1
# 30         Apr  001f425c5c6888d09bfe0e97c58cf39504eb483e         3
# 31         Apr  00202619831b0c808777fdd0f92b1266b509f1d8         3
# 33         Apr  002367a53424f7113f4f00ed33de49a408414f90         1
# 34         Apr  0024864bf75fa535c0fad9d370a43c30dafa9b70         3
# 35         Apr  0024b1838606f92712845d66b2cbeaba9ebbaac6         4
# ...        ...                                       ...       ...
# 8612217    Apr  ffe3a4aa15bb289727f825e0f4680b40f8f22f2b         4
# 8612219    Apr  ffe4a3fc23100626fbfa81779bc1bc1d39333473         4
# 8612221    Apr  ffe4f91b579729692ca1438e1f37719c8ac9acc1         1
# 8612222    Apr  ffe6dbb2606cae42e1f98d9b6990a9764ee28de0         1
# 8612223    Apr  ffe7dfac0677c1ead2520ae3c9e6519dc56a517f         4
# 8612224    Apr  ffe88635f6d6cf8c6f17ef2c2f18b9f221de98ac         3
# 8612225    Apr  ffea0a2fc05246083dbc5c3db60403aa845bad56         1
# 8612226    Apr  ffea7dad729eaec59fe7d2efd799aff684f5f36e         1
# 8612227    Apr  ffead754ea1d02712ddbbc6c786d5f145c6ecd68         3
# 8612228    Apr  ffeb0054a1b8da2085cbcdb07e18356f7b45ab68         1
# 8612230    Apr  ffeb25ed7a9ba731c664935d3a4f00aa71860f33         2
# 8612234    Apr  ffefa9e60fdcc90b976441573214cba997a0c4de         3
# 8612235    Apr  ffefe06a51b6e1e3230c2f986168b452e1e88304         1
# 8612236    Apr  fff03c53008cd2074f2ada106be140aae4934afa         1
# 8612237    Apr  fff0aebc0aa541e51e0b217faa5b3b29ebd98f64         1
# 8612238    Apr  fff10973ca2ecd1b2a8cb8d1ea3181d819916f1d         1
# 8612239    Apr  fff19d663f3bf6558ec22dd72f8e26155154cad7         1
# 8612241    Apr  fff2cf8b6896f0ca829a06d12ceb1dd63cc9bb9a         3
# 8612242    Apr  fff37820471b87c7a16b0399b35d57069e7ed626         2
# 8612244    Apr  fff58145d39b4b6f2e2af32c89c792367110e680         4
# 8612245    Apr  fff5a6f34694c7be7e634695183de329b42c0e83         1
# 8612246    Apr  fff5a89e22d229850b43d8bacb87ccb9f7ca2026         2
# 8612247    Apr  fff637e68a114df14972ac8e5cf3b5a5c2d4e765         1
# 8612248    Apr  fff7c3e52e39657046b478379d7d61c53629825c         2
# 8612249    Apr  fff7ce95461bad192e78e3a6e69c5c71f258f181         4
# 8612250    Apr  fff84e7dc0359bef35a74873669eafa8961fb4e6         4
# 8612252    Apr  fffdf55d851f5bf0d3fd5270102435ee3ec49e1e         1
# 8612253    Apr  fffe91af9df264c24423e5570e6603e63b1ea1dc         1
# 8612254    Apr  fffefca1ba70221d5da6ca8edba4430cd7a69c8c         1
# 8612255    Apr  ffffefb66c5fbc3f065a31be23c5447edf467530         3
#
#                   state date_y _merge
# 0            TAMIL NADU    May   both
# 1                 ASSAM    May   both
# 2           MAHARASHTRA    May   both
# 3         UTTAR PRADESH    May   both
# 4                 ASSAM    May   both
# 5            TAMIL NADU    May   both
# 6           WEST BENGAL    May   both
# 7                 DELHI    May   both
# 8           MAHARASHTRA    May   both
# 11          MAHARASHTRA    May   both
# 12            KARNATAKA    May   both
# 13          MAHARASHTRA    May   both
# 14        UTTAR PRADESH    May   both
# 15          WEST BENGAL    May   both
# 16           TAMIL NADU    May   both
# 18            KARNATAKA    May   both
# 19           TAMIL NADU    May   both
# 21            KARNATAKA    May   both
# 22              GUJARAT    May   both
# 23        UTTAR PRADESH    May   both
# 24              GUJARAT    May   both
# 25            TELANGANA    May   both
# 26           TAMIL NADU    May   both
# 28           TAMIL NADU    May   both
# 29            KARNATAKA    May   both
# 30          MAHARASHTRA    May   both
# 31            KARNATAKA    May   both
# 33          MAHARASHTRA    May   both
# 34            TELANGANA    May   both
# 35              GUJARAT    May   both
# ...                 ...    ...    ...
# 8612217     MAHARASHTRA    May   both
# 8612219     MAHARASHTRA    May   both
# 8612221       KARNATAKA    May   both
# 8612222          KERALA    May   both
# 8612223          KERALA    May   both
# 8612224     MAHARASHTRA    May   both
# 8612225     WEST BENGAL    May   both
# 8612226           DELHI    May   both
# 8612227       KARNATAKA    May   both
# 8612228           DELHI    May   both
# 8612230     MAHARASHTRA    May   both
# 8612234     MAHARASHTRA    May   both
# 8612235     MAHARASHTRA    May   both
# 8612236       KARNATAKA    May   both
# 8612237     MAHARASHTRA    May   both
# 8612238      TAMIL NADU    May   both
# 8612239     MAHARASHTRA    May   both
# 8612241  ANDHRA PRADESH    May   both
# 8612242     MAHARASHTRA    May   both
# 8612244         GUJARAT    May   both
# 8612245       KARNATAKA    May   both
# 8612246     MAHARASHTRA    May   both
# 8612247          KERALA    May   both
# 8612248      TAMIL NADU    May   both
# 8612249     MAHARASHTRA    May   both
# 8612250         GUJARAT    May   both
# 8612252     WEST BENGAL    May   both
# 8612253     MAHARASHTRA    May   both
# 8612254          KERALA    May   both
# 8612255       TELANGANA    May   both
#
# [6158790 rows x 6 columns]

# %%
import pandasql as ps
#df1.groupby(['udid','date']).filter(lambda x: len(x) > 1)

df1[df1.date == 'Apr'].groupby('udid').filter(lambda g: len(g) > 1).size()
#.groupby('udid').size()
#.sort_values(ascending=False)

q1 = """
SELECT operator 
FROM data_state
limit 2
"""

#print(ps.sqldf(q1, locals()))

# %%
df = pd.pivot_table(df1,values='operator',index='udid',columns='date')
df.head()
# Out:
# date                                      Apr  May
# udid
# 000001b2f4b9d139ed496267f056516edf833e80  3.0  3.0
# 000003fb76b5e01f88dfbb57ce596de197d052cd  2.0  2.0
# 00000902bb5bea2d8f865e1c6b0ace6abf6725d7  1.0  1.0
# 00000a52170c3d10d43ff77eb03c04dd164996d4  1.0  1.0
# 00000a78561f96624d409c0c1b6c297ad308ce08  1.0  1.0

# %%
df[df['Apr'] > 1].head()
# Out:
# date                                      Apr  May
# udid
# 000001b2f4b9d139ed496267f056516edf833e80  3.0  3.0
# 000003fb76b5e01f88dfbb57ce596de197d052cd  2.0  2.0
# 000016710f5ebd40631966c55bddff9893e1d52f  4.0  4.0
# 00001a76b6c34367585776ee555169435c111f29  4.0  4.0
# 00001d617ecfeeaa9e9bc65a3c7503582da7ca6f  2.0  2.0
